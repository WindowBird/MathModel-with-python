# %%
import pandas as pd

# 读取 Excel 文件
df = pd.read_excel('D:\mathercup\OneData.xlsx')

# 显示前几行数据+-
df.head()
# Out:
#    DATE: MONTH    DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed  \
# 0  DATECLKMON   DATECLKDAY        GMT            ALT                    ZIVV
# 1       months         days    HHMMSS              FT                      FT
# 2            4            7   5:32:48             135                      -5
# 3            4            7   5:32:49             136                      -9
# 4            4            7   5:32:50             136                     -12
#
#   RADIO ALT COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 0     GPRA              CAS    GNDSPEED               LGDN          WOWINAIR
# 1      FT"              KNTS        KNTS              DOWN               True
# 2        -8               30           8              DOWN              False
# 3        -8               30        8.25              DOWN              False
# 4        -8               30        8.25              DOWN              False
#
#    ... GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0  ...                  GSDEVL                  GSDEVR                LOCDEVC
# 1  ...                     DOT                     DOT                    DOT
# 2  ...                   -0.58                   -0.29                  -3.17
# 3  ...                   -0.62                   -0.36                  -2.78
# 4  ...                    0.26                    -0.1                  -3.06
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                LOCDEVL                LOCDEVR    PTCHATTRAT
# 1                    DOT                    DOT        DEG/SEC
# 2                  -3.04                  -3.28         0.0625
# 3                  -2.78                  -2.95        -0.0625
# 4                  -2.96                  -3.18        -0.0625
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0        DEPRTARPT            DESTARPT       PTCHATTRAT       FMFGROSSWT
# 1                                                DEG/SEC              KGS
# 2              机场68               机场117           0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117          -0.0625           347680
#
# [5 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205095 entries, 0 to 205094
# Data columns (total 64 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DATE: MONTH              205095 non-null  object
#  1   DATE: DAY                205095 non-null  object
#  2   GMT                      205095 non-null  object
#  3   ALTITUDE (1013)          205095 non-null  object
#  4   Inertial Vertical Speed  205095 non-null  object
#  5   RADIO ALT                205095 non-null  object
#  6   COMPUTED AIR SPD         205095 non-null  object
#  7   GROUNDSPEED              205095 non-null  object
#  8    GEAR SELECT DOWN        11897 non-null   object
#  9   WOW INDICATE INAIR       205095 non-null  object
#  10  WOW INDICATE INAIR.1     205095 non-null  object
#  11  WOW INDICATE INAIR.2     205095 non-null  object
#  12  WOW INDICATE INAIR.3     205095 non-null  object
#  13  WOW INDICATE INAIR.4     205095 non-null  object
#  14  COG NORM ACCEL           205095 non-null  object
#  15  COG NORM ACCEL.1         205095 non-null  object
#  16  COG NORM ACCEL.2         205095 non-null  object
#  17  COG NORM ACCEL.3         205095 non-null  object
#  18  COG NORM ACCEL.4         205095 non-null  object
#  19  COG NORM ACCEL.5         205095 non-null  object
#  20  COG NORM ACCEL.6         205095 non-null  object
#  21  COG NORM ACCEL.7         205095 non-null  object
#  22  COG NORM ACCEL.8         205095 non-null  object
#  23  COG NORM ACCEL.9         205095 non-null  object
#  24  PITCH ATT                205095 non-null  object
#  25  PITCH ATT.1              205095 non-null  object
#  26  PITCH ATT.2              205095 non-null  object
#  27  PITCH ATT.3              205095 non-null  object
#  28  PITCH ATT.4              205095 non-null  object
#  29  CAP CLM 1 POSN           205095 non-null  object
#  30  CAP CLM 1 POSN.1         205095 non-null  object
#  31  CAP CLM 1 POSN.2         205095 non-null  object
#  32  CAP CLM 1 POSN.3         205095 non-null  object
#  33  CAP CLM 1 POSN.4         205095 non-null  object
#  34  ROLL ATT                 205095 non-null  object
#  35  ROLL ATT.1               205095 non-null  object
#  36  CAP WHL 1 POSN           205095 non-null  object
#  37  CAP WHL 1 POSN.1         205095 non-null  object
#  38  CAP WHL 1 POSN.2         205095 non-null  object
#  39  CAP WHL 1 POSN.3         205095 non-null  object
#  40  CAP WHL 1 POSN.4         205095 non-null  object
#  41  N1 SELTED-L              205095 non-null  object
#  42  N1 SELTED-R              205095 non-null  object
#  43  MAGNETIC HEADING         205095 non-null  object
#  44  WIND DIR(ADIRU)          205095 non-null  object
#  45  WIND SPD(ADIRU)          205095 non-null  object
#  46  A/T ENGAGED              205095 non-null  object
#  47  ANY A/P ENGAGED          205095 non-null  object
#  48  TRA-L                    205095 non-null  object
#  49  TRA-L.1                  205095 non-null  object
#  50  TRA-R                    205095 non-null  object
#  51  TRA-R.1                  205095 non-null  object
#  52  RUDD POSN                205095 non-null  object
#  53  GLIDESLOPE DEV Dots (C)  205095 non-null  object
#  54  GLIDESLOPE DEV Dots (L)  205095 non-null  object
#  55  GLIDESLOPE DEV Dots (R)  205095 non-null  object
#  56  LOCALIZER DEV Dots (C)   205095 non-null  object
#  57  LOCALIZER DEV Dots (L)   205095 non-null  object
#  58  LOCALIZER DEV Dots (R)   205095 non-null  object
#  59  PITCH ATT RATE           205095 non-null  object
#  60  DEPARTURE AIRPORT        205095 non-null  object
#  61  DESTINATION AIRPORT      205095 non-null  object
#  62  PITCH ATT RATE.1         205095 non-null  object
#  63  FMF GROSS WEIGHT         205095 non-null  object
# dtypes: object(64)
# memory usage: 100.1+ MB

# %%
df[' GEAR SELECT DOWN'].fillna('unknow', inplace=True)
df.to_excel('D:\mathercup\OneData2.xlsx', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205095 entries, 0 to 205094
# Data columns (total 64 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DATE: MONTH              205095 non-null  object
#  1   DATE: DAY                205095 non-null  object
#  2   GMT                      205095 non-null  object
#  3   ALTITUDE (1013)          205095 non-null  object
#  4   Inertial Vertical Speed  205095 non-null  object
#  5   RADIO ALT                205095 non-null  object
#  6   COMPUTED AIR SPD         205095 non-null  object
#  7   GROUNDSPEED              205095 non-null  object
#  8    GEAR SELECT DOWN        205095 non-null  object
#  9   WOW INDICATE INAIR       205095 non-null  object
#  10  WOW INDICATE INAIR.1     205095 non-null  object
#  11  WOW INDICATE INAIR.2     205095 non-null  object
#  12  WOW INDICATE INAIR.3     205095 non-null  object
#  13  WOW INDICATE INAIR.4     205095 non-null  object
#  14  COG NORM ACCEL           205095 non-null  object
#  15  COG NORM ACCEL.1         205095 non-null  object
#  16  COG NORM ACCEL.2         205095 non-null  object
#  17  COG NORM ACCEL.3         205095 non-null  object
#  18  COG NORM ACCEL.4         205095 non-null  object
#  19  COG NORM ACCEL.5         205095 non-null  object
#  20  COG NORM ACCEL.6         205095 non-null  object
#  21  COG NORM ACCEL.7         205095 non-null  object
#  22  COG NORM ACCEL.8         205095 non-null  object
#  23  COG NORM ACCEL.9         205095 non-null  object
#  24  PITCH ATT                205095 non-null  object
#  25  PITCH ATT.1              205095 non-null  object
#  26  PITCH ATT.2              205095 non-null  object
#  27  PITCH ATT.3              205095 non-null  object
#  28  PITCH ATT.4              205095 non-null  object
#  29  CAP CLM 1 POSN           205095 non-null  object
#  30  CAP CLM 1 POSN.1         205095 non-null  object
#  31  CAP CLM 1 POSN.2         205095 non-null  object
#  32  CAP CLM 1 POSN.3         205095 non-null  object
#  33  CAP CLM 1 POSN.4         205095 non-null  object
#  34  ROLL ATT                 205095 non-null  object
#  35  ROLL ATT.1               205095 non-null  object
#  36  CAP WHL 1 POSN           205095 non-null  object
#  37  CAP WHL 1 POSN.1         205095 non-null  object
#  38  CAP WHL 1 POSN.2         205095 non-null  object
#  39  CAP WHL 1 POSN.3         205095 non-null  object
#  40  CAP WHL 1 POSN.4         205095 non-null  object
#  41  N1 SELTED-L              205095 non-null  object
#  42  N1 SELTED-R              205095 non-null  object
#  43  MAGNETIC HEADING         205095 non-null  object
#  44  WIND DIR(ADIRU)          205095 non-null  object
#  45  WIND SPD(ADIRU)          205095 non-null  object
#  46  A/T ENGAGED              205095 non-null  object
#  47  ANY A/P ENGAGED          205095 non-null  object
#  48  TRA-L                    205095 non-null  object
#  49  TRA-L.1                  205095 non-null  object
#  50  TRA-R                    205095 non-null  object
#  51  TRA-R.1                  205095 non-null  object
#  52  RUDD POSN                205095 non-null  object
#  53  GLIDESLOPE DEV Dots (C)  205095 non-null  object
#  54  GLIDESLOPE DEV Dots (L)  205095 non-null  object
#  55  GLIDESLOPE DEV Dots (R)  205095 non-null  object
#  56  LOCALIZER DEV Dots (C)   205095 non-null  object
#  57  LOCALIZER DEV Dots (L)   205095 non-null  object
#  58  LOCALIZER DEV Dots (R)   205095 non-null  object
#  59  PITCH ATT RATE           205095 non-null  object
#  60  DEPARTURE AIRPORT        205095 non-null  object
#  61  DESTINATION AIRPORT      205095 non-null  object
#  62  PITCH ATT RATE.1         205095 non-null  object
#  63  FMF GROSS WEIGHT         205095 non-null  object
# dtypes: object(64)
# memory usage: 100.1+ MB

# %%
df.drop_duplicates(inplace=True)#把重复行删掉覆盖原数据
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205095 entries, 0 to 205094
# Data columns (total 64 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DATE: MONTH              205095 non-null  object
#  1   DATE: DAY                205095 non-null  object
#  2   GMT                      205095 non-null  object
#  3   ALTITUDE (1013)          205095 non-null  object
#  4   Inertial Vertical Speed  205095 non-null  object
#  5   RADIO ALT                205095 non-null  object
#  6   COMPUTED AIR SPD         205095 non-null  object
#  7   GROUNDSPEED              205095 non-null  object
#  8    GEAR SELECT DOWN        205095 non-null  object
#  9   WOW INDICATE INAIR       205095 non-null  object
#  10  WOW INDICATE INAIR.1     205095 non-null  object
#  11  WOW INDICATE INAIR.2     205095 non-null  object
#  12  WOW INDICATE INAIR.3     205095 non-null  object
#  13  WOW INDICATE INAIR.4     205095 non-null  object
#  14  COG NORM ACCEL           205095 non-null  object
#  15  COG NORM ACCEL.1         205095 non-null  object
#  16  COG NORM ACCEL.2         205095 non-null  object
#  17  COG NORM ACCEL.3         205095 non-null  object
#  18  COG NORM ACCEL.4         205095 non-null  object
#  19  COG NORM ACCEL.5         205095 non-null  object
#  20  COG NORM ACCEL.6         205095 non-null  object
#  21  COG NORM ACCEL.7         205095 non-null  object
#  22  COG NORM ACCEL.8         205095 non-null  object
#  23  COG NORM ACCEL.9         205095 non-null  object
#  24  PITCH ATT                205095 non-null  object
#  25  PITCH ATT.1              205095 non-null  object
#  26  PITCH ATT.2              205095 non-null  object
#  27  PITCH ATT.3              205095 non-null  object
#  28  PITCH ATT.4              205095 non-null  object
#  29  CAP CLM 1 POSN           205095 non-null  object
#  30  CAP CLM 1 POSN.1         205095 non-null  object
#  31  CAP CLM 1 POSN.2         205095 non-null  object
#  32  CAP CLM 1 POSN.3         205095 non-null  object
#  33  CAP CLM 1 POSN.4         205095 non-null  object
#  34  ROLL ATT                 205095 non-null  object
#  35  ROLL ATT.1               205095 non-null  object
#  36  CAP WHL 1 POSN           205095 non-null  object
#  37  CAP WHL 1 POSN.1         205095 non-null  object
#  38  CAP WHL 1 POSN.2         205095 non-null  object
#  39  CAP WHL 1 POSN.3         205095 non-null  object
#  40  CAP WHL 1 POSN.4         205095 non-null  object
#  41  N1 SELTED-L              205095 non-null  object
#  42  N1 SELTED-R              205095 non-null  object
#  43  MAGNETIC HEADING         205095 non-null  object
#  44  WIND DIR(ADIRU)          205095 non-null  object
#  45  WIND SPD(ADIRU)          205095 non-null  object
#  46  A/T ENGAGED              205095 non-null  object
#  47  ANY A/P ENGAGED          205095 non-null  object
#  48  TRA-L                    205095 non-null  object
#  49  TRA-L.1                  205095 non-null  object
#  50  TRA-R                    205095 non-null  object
#  51  TRA-R.1                  205095 non-null  object
#  52  RUDD POSN                205095 non-null  object
#  53  GLIDESLOPE DEV Dots (C)  205095 non-null  object
#  54  GLIDESLOPE DEV Dots (L)  205095 non-null  object
#  55  GLIDESLOPE DEV Dots (R)  205095 non-null  object
#  56  LOCALIZER DEV Dots (C)   205095 non-null  object
#  57  LOCALIZER DEV Dots (L)   205095 non-null  object
#  58  LOCALIZER DEV Dots (R)   205095 non-null  object
#  59  PITCH ATT RATE           205095 non-null  object
#  60  DEPARTURE AIRPORT        205095 non-null  object
#  61  DESTINATION AIRPORT      205095 non-null  object
#  62  PITCH ATT RATE.1         205095 non-null  object
#  63  FMF GROSS WEIGHT         205095 non-null  object
# dtypes: object(64)
# memory usage: 101.7+ MB

# %%
# 设置最大列宽为 None，使得所有列都完整显示
pd.set_option('display.max_columns', 60)

# %%
df.describe().T
# Out:
#                           count unique       top    freq
# DATE: MONTH              205095      3         4  205093
# DATE: DAY                205095      6         9   72641
# GMT                      205095  83734  12:41:44       5
# ALTITUDE (1013)          205095  18268     31000    8188
# Inertial Vertical Speed  205095   6099         0    4705
# ...                         ...    ...       ...     ...
# PITCH ATT RATE           205095     66         0   86207
# DEPARTURE AIRPORT        205095      7      机场68  103184
# DESTINATION AIRPORT      205095      7      机场68  101909
# PITCH ATT RATE.1         205095     66         0   86207
# FMF GROSS WEIGHT         205095    961    238080     612
#
# [64 rows x 4 columns]

# %%
# 删除名为 'DATE: MONTH' 的列
df.drop('DATE: MONTH', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205095 entries, 0 to 205094
# Data columns (total 63 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DATE: DAY                205095 non-null  object
#  1   GMT                      205095 non-null  object
#  2   ALTITUDE (1013)          205095 non-null  object
#  3   Inertial Vertical Speed  205095 non-null  object
#  4   RADIO ALT                205095 non-null  object
#  5   COMPUTED AIR SPD         205095 non-null  object
#  6   GROUNDSPEED              205095 non-null  object
#  7    GEAR SELECT DOWN        205095 non-null  object
#  8   WOW INDICATE INAIR       205095 non-null  object
#  9   WOW INDICATE INAIR.1     205095 non-null  object
#  10  WOW INDICATE INAIR.2     205095 non-null  object
#  11  WOW INDICATE INAIR.3     205095 non-null  object
#  12  WOW INDICATE INAIR.4     205095 non-null  object
#  13  COG NORM ACCEL           205095 non-null  object
#  14  COG NORM ACCEL.1         205095 non-null  object
#  15  COG NORM ACCEL.2         205095 non-null  object
#  16  COG NORM ACCEL.3         205095 non-null  object
#  17  COG NORM ACCEL.4         205095 non-null  object
#  18  COG NORM ACCEL.5         205095 non-null  object
#  19  COG NORM ACCEL.6         205095 non-null  object
#  20  COG NORM ACCEL.7         205095 non-null  object
#  21  COG NORM ACCEL.8         205095 non-null  object
#  22  COG NORM ACCEL.9         205095 non-null  object
#  23  PITCH ATT                205095 non-null  object
#  24  PITCH ATT.1              205095 non-null  object
#  25  PITCH ATT.2              205095 non-null  object
#  26  PITCH ATT.3              205095 non-null  object
#  27  PITCH ATT.4              205095 non-null  object
#  28  CAP CLM 1 POSN           205095 non-null  object
#  29  CAP CLM 1 POSN.1         205095 non-null  object
#  30  CAP CLM 1 POSN.2         205095 non-null  object
#  31  CAP CLM 1 POSN.3         205095 non-null  object
#  32  CAP CLM 1 POSN.4         205095 non-null  object
#  33  ROLL ATT                 205095 non-null  object
#  34  ROLL ATT.1               205095 non-null  object
#  35  CAP WHL 1 POSN           205095 non-null  object
#  36  CAP WHL 1 POSN.1         205095 non-null  object
#  37  CAP WHL 1 POSN.2         205095 non-null  object
#  38  CAP WHL 1 POSN.3         205095 non-null  object
#  39  CAP WHL 1 POSN.4         205095 non-null  object
#  40  N1 SELTED-L              205095 non-null  object
#  41  N1 SELTED-R              205095 non-null  object
#  42  MAGNETIC HEADING         205095 non-null  object
#  43  WIND DIR(ADIRU)          205095 non-null  object
#  44  WIND SPD(ADIRU)          205095 non-null  object
#  45  A/T ENGAGED              205095 non-null  object
#  46  ANY A/P ENGAGED          205095 non-null  object
#  47  TRA-L                    205095 non-null  object
#  48  TRA-L.1                  205095 non-null  object
#  49  TRA-R                    205095 non-null  object
#  50  TRA-R.1                  205095 non-null  object
#  51  RUDD POSN                205095 non-null  object
#  52  GLIDESLOPE DEV Dots (C)  205095 non-null  object
#  53  GLIDESLOPE DEV Dots (L)  205095 non-null  object
#  54  GLIDESLOPE DEV Dots (R)  205095 non-null  object
#  55  LOCALIZER DEV Dots (C)   205095 non-null  object
#  56  LOCALIZER DEV Dots (L)   205095 non-null  object
#  57  LOCALIZER DEV Dots (R)   205095 non-null  object
#  58  PITCH ATT RATE           205095 non-null  object
#  59  DEPARTURE AIRPORT        205095 non-null  object
#  60  DESTINATION AIRPORT      205095 non-null  object
#  61  PITCH ATT RATE.1         205095 non-null  object
#  62  FMF GROSS WEIGHT         205095 non-null  object
# dtypes: object(63)
# memory usage: 100.1+ MB

# %%
df.replace({'WOW INDICATE INAIR': 'False', 'WOW INDICATE INAIR.1': 'False', 'WOW INDICATE INAIR.2': 'False', 'WOW INDICATE INAIR.3': 'False', 'WOW INDICATE INAIR.4': 'False'}, 0, inplace=True)

# %%
df.head()
# Out:
#      DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0  DATECLKDAY        GMT            ALT                    ZIVV      GPRA
# 1         days    HHMMSS              FT                      FT      FT"
# 2            7   5:32:48             135                      -5        -8
# 3            7   5:32:49             136                      -9        -8
# 4            7   5:32:50             136                     -12        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 0             CAS    GNDSPEED               LGDN          WOWINAIR
# 1             KNTS        KNTS              DOWN               True
# 2               30           8              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30        8.25              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 0            WOWINAIR             WOWINAIR             WOWINAIR
# 1                 True                 True                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0            WOWINAIR       CGBRMACL         CGBRMACL         CGBRMACL
# 1                 True           GEES             GEES             GEES
# 2                False         1.0078           1.0039           1.0039
# 3                False         0.9844           0.9883           1.0273
# 4                False         1.0039           0.9922           1.0117
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0        CGBRMACL         CGBRMACL         CGBRMACL         CGBRMACL
# 1             GEES             GEES             GEES             GEES
# 2           0.9805           0.9922           1.0078           1.0156
# 3           1.0156           0.9922           0.9844           0.9883
# 4           0.9883                1           1.0078           1.0117
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 0        CGBRMACL         CGBRMACL         CGBRMACL     PITCH       PITCH
# 1             GEES             GEES             GEES      DEGS        DEGS
# 2           1.0078                1           0.9922   -0.3516     -0.3516
# 3           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 4           1.0117           0.9961           0.9727   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 0      PITCH       PITCH       PITCH       CCOL1POS         CCOL1POS   ...
# 1        DEGS        DEGS        DEGS        IN LVDT          IN LVDT  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 0    ROLL       ROLL       CWHL1POS         CWHL1POS         CWHL1POS
# 1     DEGS       DEGS        IN LVDT          IN LVDT          IN LVDT
# 2   0.0879     0.0879         0.0115           0.0115           0.0115
# 3   0.0879     0.0879         0.0104           0.0104           0.0115
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 0        CWHL1POS         CWHL1POS        N1.L        N1.R        MAGHEADNG
# 1          IN LVDT          IN LVDT                                     DEGS
# 2           0.0115           0.0115        21.4        21.4            178.2
# 3           0.0104           0.0115        21.4        21.5            178.4
# 4           0.0104           0.0104        21.4        21.5            178.6
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 0     WINDIRCTRU       WINDSPEED    TMATENGD           APENG    TRA.L
# 1             DEG            KNTS     ENGAGED              ON      DEG
# 2               0               0     DISENGD             OFF  34.0137
# 3               0               0     DISENGD             OFF  34.0137
# 4               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 0   TRA.L    TRA.R    TRA.R   RUDPOSN                   GSDEVC
# 1      DEG      DEG      DEG        IN                     DOT
# 2  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 3  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 4  33.9697  34.0576  34.0576   -0.2578                    0.08
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0                  GSDEVL                  GSDEVR                LOCDEVC
# 1                     DOT                     DOT                    DOT
# 2                   -0.58                   -0.29                  -3.17
# 3                   -0.62                   -0.36                  -2.78
# 4                    0.26                    -0.1                  -3.06
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                LOCDEVL                LOCDEVR    PTCHATTRAT
# 1                    DOT                    DOT        DEG/SEC
# 2                  -3.04                  -3.28         0.0625
# 3                  -2.78                  -2.95        -0.0625
# 4                  -2.96                  -3.18        -0.0625
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0        DEPRTARPT            DESTARPT       PTCHATTRAT       FMFGROSSWT
# 1                                                DEG/SEC              KGS
# 2              机场68               机场117           0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117          -0.0625           347680
#
# [5 rows x 63 columns]

# %%
df['WOW INDICATE INAIR'] = df['WOW INDICATE INAIR'].replace('False', 0)

# %%
df.head()
# Out:
#      DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0  DATECLKDAY        GMT            ALT                    ZIVV      GPRA
# 1         days    HHMMSS              FT                      FT      FT"
# 2            7   5:32:48             135                      -5        -8
# 3            7   5:32:49             136                      -9        -8
# 4            7   5:32:50             136                     -12        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 0             CAS    GNDSPEED               LGDN          WOWINAIR
# 1             KNTS        KNTS              DOWN               True
# 2               30           8              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30        8.25              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 0            WOWINAIR             WOWINAIR             WOWINAIR
# 1                 True                 True                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0            WOWINAIR       CGBRMACL         CGBRMACL         CGBRMACL
# 1                 True           GEES             GEES             GEES
# 2                False         1.0078           1.0039           1.0039
# 3                False         0.9844           0.9883           1.0273
# 4                False         1.0039           0.9922           1.0117
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0        CGBRMACL         CGBRMACL         CGBRMACL         CGBRMACL
# 1             GEES             GEES             GEES             GEES
# 2           0.9805           0.9922           1.0078           1.0156
# 3           1.0156           0.9922           0.9844           0.9883
# 4           0.9883                1           1.0078           1.0117
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 0        CGBRMACL         CGBRMACL         CGBRMACL     PITCH       PITCH
# 1             GEES             GEES             GEES      DEGS        DEGS
# 2           1.0078                1           0.9922   -0.3516     -0.3516
# 3           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 4           1.0117           0.9961           0.9727   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 0      PITCH       PITCH       PITCH       CCOL1POS         CCOL1POS   ...
# 1        DEGS        DEGS        DEGS        IN LVDT          IN LVDT  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 0    ROLL       ROLL       CWHL1POS         CWHL1POS         CWHL1POS
# 1     DEGS       DEGS        IN LVDT          IN LVDT          IN LVDT
# 2   0.0879     0.0879         0.0115           0.0115           0.0115
# 3   0.0879     0.0879         0.0104           0.0104           0.0115
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 0        CWHL1POS         CWHL1POS        N1.L        N1.R        MAGHEADNG
# 1          IN LVDT          IN LVDT                                     DEGS
# 2           0.0115           0.0115        21.4        21.4            178.2
# 3           0.0104           0.0115        21.4        21.5            178.4
# 4           0.0104           0.0104        21.4        21.5            178.6
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 0     WINDIRCTRU       WINDSPEED    TMATENGD           APENG    TRA.L
# 1             DEG            KNTS     ENGAGED              ON      DEG
# 2               0               0     DISENGD             OFF  34.0137
# 3               0               0     DISENGD             OFF  34.0137
# 4               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 0   TRA.L    TRA.R    TRA.R   RUDPOSN                   GSDEVC
# 1      DEG      DEG      DEG        IN                     DOT
# 2  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 3  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 4  33.9697  34.0576  34.0576   -0.2578                    0.08
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0                  GSDEVL                  GSDEVR                LOCDEVC
# 1                     DOT                     DOT                    DOT
# 2                   -0.58                   -0.29                  -3.17
# 3                   -0.62                   -0.36                  -2.78
# 4                    0.26                    -0.1                  -3.06
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                LOCDEVL                LOCDEVR    PTCHATTRAT
# 1                    DOT                    DOT        DEG/SEC
# 2                  -3.04                  -3.28         0.0625
# 3                  -2.78                  -2.95        -0.0625
# 4                  -2.96                  -3.18        -0.0625
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0        DEPRTARPT            DESTARPT       PTCHATTRAT       FMFGROSSWT
# 1                                                DEG/SEC              KGS
# 2              机场68               机场117           0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117          -0.0625           347680
#
# [5 rows x 63 columns]

# %%
df.drop(0, inplace=True)
df.head()
# Out:
#   DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 1      days    HHMMSS              FT                      FT      FT"
# 2         7   5:32:48             135                      -5        -8
# 3         7   5:32:49             136                      -9        -8
# 4         7   5:32:50             136                     -12        -8
# 5         7   5:32:51             135                      -4        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 1             KNTS        KNTS              DOWN               True
# 2               30           8              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30        8.25              DOWN              False
# 5               30        8.25              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 1                 True                 True                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
# 5                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 1                 True           GEES             GEES             GEES
# 2                False         1.0078           1.0039           1.0039
# 3                False         0.9844           0.9883           1.0273
# 4                False         1.0039           0.9922           1.0117
# 5                False         0.9922           0.9805           0.9727
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 1             GEES             GEES             GEES             GEES
# 2           0.9805           0.9922           1.0078           1.0156
# 3           1.0156           0.9922           0.9844           0.9883
# 4           0.9883                1           1.0078           1.0117
# 5           0.9922           1.0273           1.0156           0.9883
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 1             GEES             GEES             GEES      DEGS        DEGS
# 2           1.0078                1           0.9922   -0.3516     -0.3516
# 3           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 4           1.0117           0.9961           0.9727   -0.3516     -0.3516
# 5           0.9922           1.0195           0.9883   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 1        DEGS        DEGS        DEGS        IN LVDT          IN LVDT  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 5     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 1     DEGS       DEGS        IN LVDT          IN LVDT          IN LVDT
# 2   0.0879     0.0879         0.0115           0.0115           0.0115
# 3   0.0879     0.0879         0.0104           0.0104           0.0115
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
# 5   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 1          IN LVDT          IN LVDT                                     DEGS
# 2           0.0115           0.0115        21.4        21.4            178.2
# 3           0.0104           0.0115        21.4        21.5            178.4
# 4           0.0104           0.0104        21.4        21.5            178.6
# 5           0.0104           0.0104        21.4        21.5            178.7
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 1             DEG            KNTS     ENGAGED              ON      DEG
# 2               0               0     DISENGD             OFF  34.0137
# 3               0               0     DISENGD             OFF  34.0137
# 4               0               0     DISENGD             OFF  33.9697
# 5               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 1      DEG      DEG      DEG        IN                     DOT
# 2  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 3  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 4  33.9697  34.0576  34.0576   -0.2578                    0.08
# 5  33.9697  34.0576  34.0576   -0.2578                   -0.17
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 1                     DOT                     DOT                    DOT
# 2                   -0.58                   -0.29                  -3.17
# 3                   -0.62                   -0.36                  -2.78
# 4                    0.26                    -0.1                  -3.06
# 5                   -0.21                    0.13                  -2.78
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 1                    DOT                    DOT        DEG/SEC
# 2                  -3.04                  -3.28         0.0625
# 3                  -2.78                  -2.95        -0.0625
# 4                  -2.96                  -3.18        -0.0625
# 5                  -2.78                  -2.92        -0.0625
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 1                                                DEG/SEC              KGS
# 2              机场68               机场117           0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117          -0.0625           347680
# 5              机场68               机场117          -0.0625           347680
#
# [5 rows x 63 columns]

# %%
df.drop(1, inplace=True)
df.head()
# Out:
#   DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 2         7   5:32:48             135                      -5        -8
# 3         7   5:32:49             136                      -9        -8
# 4         7   5:32:50             136                     -12        -8
# 5         7   5:32:51             135                      -4        -8
# 6         7   5:32:52             136                      -3        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 2               30           8              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30        8.25              DOWN              False
# 5               30        8.25              DOWN              False
# 6               30         8.5              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
# 5                False                False                False
# 6                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 2                False         1.0078           1.0039           1.0039
# 3                False         0.9844           0.9883           1.0273
# 4                False         1.0039           0.9922           1.0117
# 5                False         0.9922           0.9805           0.9727
# 6                False         1.0078           1.0039                1
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 2           0.9805           0.9922           1.0078           1.0156
# 3           1.0156           0.9922           0.9844           0.9883
# 4           0.9883                1           1.0078           1.0117
# 5           0.9922           1.0273           1.0156           0.9883
# 6           0.9844           0.9844           1.0117           1.0156
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 2           1.0078                1           0.9922   -0.3516     -0.3516
# 3           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 4           1.0117           0.9961           0.9727   -0.3516     -0.3516
# 5           0.9922           1.0195           0.9883   -0.3516     -0.3516
# 6           1.0039           0.9883           1.0078   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 5     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 6     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 2   0.0879     0.0879         0.0115           0.0115           0.0115
# 3   0.0879     0.0879         0.0104           0.0104           0.0115
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
# 5   0.0879     0.0879         0.0104           0.0104           0.0104
# 6   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 2           0.0115           0.0115        21.4        21.4            178.2
# 3           0.0104           0.0115        21.4        21.5            178.4
# 4           0.0104           0.0104        21.4        21.5            178.6
# 5           0.0104           0.0104        21.4        21.5            178.7
# 6           0.0115           0.0104        21.4        21.5            178.7
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 2               0               0     DISENGD             OFF  34.0137
# 3               0               0     DISENGD             OFF  34.0137
# 4               0               0     DISENGD             OFF  33.9697
# 5               0               0     DISENGD             OFF  33.9697
# 6               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 2  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 3  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 4  33.9697  34.0576  34.0576   -0.2578                    0.08
# 5  33.9697  34.0576  34.0576   -0.2578                   -0.17
# 6  33.9697  34.0576  34.0576   -0.2578                   -0.05
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 2                   -0.58                   -0.29                  -3.17
# 3                   -0.62                   -0.36                  -2.78
# 4                    0.26                    -0.1                  -3.06
# 5                   -0.21                    0.13                  -2.78
# 6                       0                   -0.48                  -2.94
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 2                  -3.04                  -3.28         0.0625
# 3                  -2.78                  -2.95        -0.0625
# 4                  -2.96                  -3.18        -0.0625
# 5                  -2.78                  -2.92        -0.0625
# 6                  -2.88                  -3.09              0
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 2              机场68               机场117           0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117          -0.0625           347680
# 5              机场68               机场117          -0.0625           347680
# 6              机场68               机场117                0           347680
#
# [5 rows x 63 columns]

# %%
df.index=range(df.shape[0])#恢复索引

# %%
df.head()
# Out:
#   DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0         7   5:32:48             135                      -5        -8
# 1         7   5:32:49             136                      -9        -8
# 2         7   5:32:50             136                     -12        -8
# 3         7   5:32:51             135                      -4        -8
# 4         7   5:32:52             136                      -3        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 0               30           8              DOWN              False
# 1               30        8.25              DOWN              False
# 2               30        8.25              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30         8.5              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0                False         1.0078           1.0039           1.0039
# 1                False         0.9844           0.9883           1.0273
# 2                False         1.0039           0.9922           1.0117
# 3                False         0.9922           0.9805           0.9727
# 4                False         1.0078           1.0039                1
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0           0.9805           0.9922           1.0078           1.0156
# 1           1.0156           0.9922           0.9844           0.9883
# 2           0.9883                1           1.0078           1.0117
# 3           0.9922           1.0273           1.0156           0.9883
# 4           0.9844           0.9844           1.0117           1.0156
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 0           1.0078                1           0.9922   -0.3516     -0.3516
# 1           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 2           1.0117           0.9961           0.9727   -0.3516     -0.3516
# 3           0.9922           1.0195           0.9883   -0.3516     -0.3516
# 4           1.0039           0.9883           1.0078   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 0     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 1     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 0   0.0879     0.0879         0.0115           0.0115           0.0115
# 1   0.0879     0.0879         0.0104           0.0104           0.0115
# 2   0.0879     0.0879         0.0104           0.0104           0.0104
# 3   0.0879     0.0879         0.0104           0.0104           0.0104
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 0           0.0115           0.0115        21.4        21.4            178.2
# 1           0.0104           0.0115        21.4        21.5            178.4
# 2           0.0104           0.0104        21.4        21.5            178.6
# 3           0.0104           0.0104        21.4        21.5            178.7
# 4           0.0115           0.0104        21.4        21.5            178.7
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 0               0               0     DISENGD             OFF  34.0137
# 1               0               0     DISENGD             OFF  34.0137
# 2               0               0     DISENGD             OFF  33.9697
# 3               0               0     DISENGD             OFF  33.9697
# 4               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 0  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 1  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 2  33.9697  34.0576  34.0576   -0.2578                    0.08
# 3  33.9697  34.0576  34.0576   -0.2578                   -0.17
# 4  33.9697  34.0576  34.0576   -0.2578                   -0.05
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0                   -0.58                   -0.29                  -3.17
# 1                   -0.62                   -0.36                  -2.78
# 2                    0.26                    -0.1                  -3.06
# 3                   -0.21                    0.13                  -2.78
# 4                       0                   -0.48                  -2.94
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                  -3.04                  -3.28         0.0625
# 1                  -2.78                  -2.95        -0.0625
# 2                  -2.96                  -3.18        -0.0625
# 3                  -2.78                  -2.92        -0.0625
# 4                  -2.88                  -3.09              0
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0              机场68               机场117           0.0625           347680
# 1              机场68               机场117          -0.0625           347680
# 2              机场68               机场117          -0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117                0           347680
#
# [5 rows x 63 columns]

# %%
df['WOW INDICATE INAIR'] = df['WOW INDICATE INAIR'].replace('False', 0)

# %%
df.head()
# Out:
#   DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0         7   5:32:48             135                      -5        -8
# 1         7   5:32:49             136                      -9        -8
# 2         7   5:32:50             136                     -12        -8
# 3         7   5:32:51             135                      -4        -8
# 4         7   5:32:52             136                      -3        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN WOW INDICATE INAIR  \
# 0               30           8              DOWN              False
# 1               30        8.25              DOWN              False
# 2               30        8.25              DOWN              False
# 3               30        8.25              DOWN              False
# 4               30         8.5              DOWN              False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0                False         1.0078           1.0039           1.0039
# 1                False         0.9844           0.9883           1.0273
# 2                False         1.0039           0.9922           1.0117
# 3                False         0.9922           0.9805           0.9727
# 4                False         1.0078           1.0039                1
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0           0.9805           0.9922           1.0078           1.0156
# 1           1.0156           0.9922           0.9844           0.9883
# 2           0.9883                1           1.0078           1.0117
# 3           0.9922           1.0273           1.0156           0.9883
# 4           0.9844           0.9844           1.0117           1.0156
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 0           1.0078                1           0.9922   -0.3516     -0.3516
# 1           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 2           1.0117           0.9961           0.9727   -0.3516     -0.3516
# 3           0.9922           1.0195           0.9883   -0.3516     -0.3516
# 4           1.0039           0.9883           1.0078   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 0     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 1     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 0   0.0879     0.0879         0.0115           0.0115           0.0115
# 1   0.0879     0.0879         0.0104           0.0104           0.0115
# 2   0.0879     0.0879         0.0104           0.0104           0.0104
# 3   0.0879     0.0879         0.0104           0.0104           0.0104
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 0           0.0115           0.0115        21.4        21.4            178.2
# 1           0.0104           0.0115        21.4        21.5            178.4
# 2           0.0104           0.0104        21.4        21.5            178.6
# 3           0.0104           0.0104        21.4        21.5            178.7
# 4           0.0115           0.0104        21.4        21.5            178.7
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 0               0               0     DISENGD             OFF  34.0137
# 1               0               0     DISENGD             OFF  34.0137
# 2               0               0     DISENGD             OFF  33.9697
# 3               0               0     DISENGD             OFF  33.9697
# 4               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 0  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 1  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 2  33.9697  34.0576  34.0576   -0.2578                    0.08
# 3  33.9697  34.0576  34.0576   -0.2578                   -0.17
# 4  33.9697  34.0576  34.0576   -0.2578                   -0.05
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0                   -0.58                   -0.29                  -3.17
# 1                   -0.62                   -0.36                  -2.78
# 2                    0.26                    -0.1                  -3.06
# 3                   -0.21                    0.13                  -2.78
# 4                       0                   -0.48                  -2.94
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                  -3.04                  -3.28         0.0625
# 1                  -2.78                  -2.95        -0.0625
# 2                  -2.96                  -3.18        -0.0625
# 3                  -2.78                  -2.92        -0.0625
# 4                  -2.88                  -3.09              0
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0              机场68               机场117           0.0625           347680
# 1              机场68               机场117          -0.0625           347680
# 2              机场68               机场117          -0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117                0           347680
#
# [5 rows x 63 columns]

# %%
word_to_value = {'False': 0, 'True': 1}
df['WOW INDICATE INAIR'] = df['WOW INDICATE INAIR'].replace(word_to_value)
df.head()
# Out:
#   DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0         7   5:32:48             135                      -5        -8
# 1         7   5:32:49             136                      -9        -8
# 2         7   5:32:50             136                     -12        -8
# 3         7   5:32:51             135                      -4        -8
# 4         7   5:32:52             136                      -3        -8
#
#   COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN  WOW INDICATE INAIR  \
# 0               30           8              DOWN               False
# 1               30        8.25              DOWN               False
# 2               30        8.25              DOWN               False
# 3               30        8.25              DOWN               False
# 4               30         8.5              DOWN               False
#
#   WOW INDICATE INAIR.1 WOW INDICATE INAIR.2 WOW INDICATE INAIR.3  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0                False         1.0078           1.0039           1.0039
# 1                False         0.9844           0.9883           1.0273
# 2                False         1.0039           0.9922           1.0117
# 3                False         0.9922           0.9805           0.9727
# 4                False         1.0078           1.0039                1
#
#   COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0           0.9805           0.9922           1.0078           1.0156
# 1           1.0156           0.9922           0.9844           0.9883
# 2           0.9883                1           1.0078           1.0117
# 3           0.9922           1.0273           1.0156           0.9883
# 4           0.9844           0.9844           1.0117           1.0156
#
#   COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT PITCH ATT.1  \
# 0           1.0078                1           0.9922   -0.3516     -0.3516
# 1           0.9961           1.0039           1.0195   -0.3516     -0.3516
# 2           1.0117           0.9961           0.9727   -0.3516     -0.3516
# 3           0.9922           1.0195           0.9883   -0.3516     -0.3516
# 4           1.0039           0.9883           1.0078   -0.3516     -0.3516
#
#   PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN CAP CLM 1 POSN.1  ...  \
# 0     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 1     -0.3516     -0.3516     -0.3516         -0.001          -0.0021  ...
# 2     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 3     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
# 4     -0.3516     -0.3516     -0.3516         -0.001           -0.001  ...
#
#   ROLL ATT ROLL ATT.1 CAP WHL 1 POSN CAP WHL 1 POSN.1 CAP WHL 1 POSN.2  \
# 0   0.0879     0.0879         0.0115           0.0115           0.0115
# 1   0.0879     0.0879         0.0104           0.0104           0.0115
# 2   0.0879     0.0879         0.0104           0.0104           0.0104
# 3   0.0879     0.0879         0.0104           0.0104           0.0104
# 4   0.0879     0.0879         0.0104           0.0104           0.0104
#
#   CAP WHL 1 POSN.3 CAP WHL 1 POSN.4 N1 SELTED-L N1 SELTED-R MAGNETIC HEADING  \
# 0           0.0115           0.0115        21.4        21.4            178.2
# 1           0.0104           0.0115        21.4        21.5            178.4
# 2           0.0104           0.0104        21.4        21.5            178.6
# 3           0.0104           0.0104        21.4        21.5            178.7
# 4           0.0115           0.0104        21.4        21.5            178.7
#
#   WIND DIR(ADIRU) WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  \
# 0               0               0     DISENGD             OFF  34.0137
# 1               0               0     DISENGD             OFF  34.0137
# 2               0               0     DISENGD             OFF  33.9697
# 3               0               0     DISENGD             OFF  33.9697
# 4               0               0     DISENGD             OFF  33.9697
#
#    TRA-L.1    TRA-R  TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C)  \
# 0  34.0137  34.0576  34.0576   -0.2617                   -0.49
# 1  34.0137  34.0576  34.0576   -0.2578                   -0.47
# 2  33.9697  34.0576  34.0576   -0.2578                    0.08
# 3  33.9697  34.0576  34.0576   -0.2578                   -0.17
# 4  33.9697  34.0576  34.0576   -0.2578                   -0.05
#
#   GLIDESLOPE DEV Dots (L) GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C)  \
# 0                   -0.58                   -0.29                  -3.17
# 1                   -0.62                   -0.36                  -2.78
# 2                    0.26                    -0.1                  -3.06
# 3                   -0.21                    0.13                  -2.78
# 4                       0                   -0.48                  -2.94
#
#   LOCALIZER DEV Dots (L) LOCALIZER DEV Dots (R) PITCH ATT RATE  \
# 0                  -3.04                  -3.28         0.0625
# 1                  -2.78                  -2.95        -0.0625
# 2                  -2.96                  -3.18        -0.0625
# 3                  -2.78                  -2.92        -0.0625
# 4                  -2.88                  -3.09              0
#
#   DEPARTURE AIRPORT DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0              机场68               机场117           0.0625           347680
# 1              机场68               机场117          -0.0625           347680
# 2              机场68               机场117          -0.0625           347680
# 3              机场68               机场117          -0.0625           347680
# 4              机场68               机场117                0           347680
#
# [5 rows x 63 columns]

# %%
# 假设你的处理后的数据存储在名为 processed_data 的 DataFrame 对象中
# 设置要保存的文件名和文件路径
file_path = "D:\mathercup\OneData3.xlsx"

# 使用 to_excel() 方法将数据保存到 Excel 文件中
df.to_excel(file_path, index=False)

# %%
y=df.iloc[:,df.columns=="WOW INDICATE INAIR"]

# %%
y
# Out:
#         WOW INDICATE INAIR
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 205088                   0
# 205089                   0
# 205090                   0
# 205091                   0
# 205092                   0
#
# [205093 rows x 1 columns]

# %%
df
# Out:
#        DATE: DAY       GMT ALTITUDE (1013) Inertial Vertical Speed RADIO ALT  \
# 0              7   5:32:48             135                      -5        -8
# 1              7   5:32:49             136                      -9        -8
# 2              7   5:32:50             136                     -12        -8
# 3              7   5:32:51             135                      -4        -8
# 4              7   5:32:52             136                      -3        -8
# ...          ...       ...             ...                     ...       ...
# 205088        10  14:04:20            -107                       0        -8
# 205089        10  14:04:21            -107                       0        -8
# 205090        10  14:04:22            -108                       8        -8
# 205091        10  14:04:23            -108                      14        -8
# 205092        10  14:04:24            -108                      15        -8
#
#        COMPUTED AIR SPD GROUNDSPEED  GEAR SELECT DOWN  WOW INDICATE INAIR  \
# 0                    30           8              DOWN                   0
# 1                    30        8.25              DOWN                   0
# 2                    30        8.25              DOWN                   0
# 3                    30        8.25              DOWN                   0
# 4                    30         8.5              DOWN                   0
# ...                 ...         ...               ...                 ...
# 205088               30        0.75              DOWN                   0
# 205089               30        0.75              DOWN                   0
# 205090               30        0.75              DOWN                   0
# 205091               30        0.75              DOWN                   0
# 205092               30        0.75              DOWN                   0
#
#         WOW INDICATE INAIR.1  WOW INDICATE INAIR.2  WOW INDICATE INAIR.3  \
# 0                          0                     0                     0
# 1                          0                     0                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 205088                     0                     0                     0
# 205089                     0                     0                     0
# 205090                     0                     0                     0
# 205091                     0                     0                     0
# 205092                     0                     0                     0
#
#         WOW INDICATE INAIR.4 COG NORM ACCEL COG NORM ACCEL.1 COG NORM ACCEL.2  \
# 0                          0         1.0078           1.0039           1.0039
# 1                          0         0.9844           0.9883           1.0273
# 2                          0         1.0039           0.9922           1.0117
# 3                          0         0.9922           0.9805           0.9727
# 4                          0         1.0078           1.0039                1
# ...                      ...            ...              ...              ...
# 205088                     0              1           0.9922                1
# 205089                     0         0.9961           0.9961           0.9961
# 205090                     0         1.0078                1           0.9961
# 205091                     0         1.0078                1           0.9883
# 205092                     0         0.9961           0.9922                1
#
#        COG NORM ACCEL.3 COG NORM ACCEL.4 COG NORM ACCEL.5 COG NORM ACCEL.6  \
# 0                0.9805           0.9922           1.0078           1.0156
# 1                1.0156           0.9922           0.9844           0.9883
# 2                0.9883                1           1.0078           1.0117
# 3                0.9922           1.0273           1.0156           0.9883
# 4                0.9844           0.9844           1.0117           1.0156
# ...                 ...              ...              ...              ...
# 205088           0.9961           0.9961                1           0.9883
# 205089           0.9961           0.9961                1           1.0039
# 205090           0.9922           0.9961                1           1.0039
# 205091           0.9922                1                1                1
# 205092           0.9961                1           1.0039           0.9922
#
#        COG NORM ACCEL.7 COG NORM ACCEL.8 COG NORM ACCEL.9 PITCH ATT  \
# 0                1.0078                1           0.9922   -0.3516
# 1                0.9961           1.0039           1.0195   -0.3516
# 2                1.0117           0.9961           0.9727   -0.3516
# 3                0.9922           1.0195           0.9883   -0.3516
# 4                1.0039           0.9883           1.0078   -0.3516
# ...                 ...              ...              ...       ...
# 205088                1           0.9961           1.0078   -0.7031
# 205089           1.0117           0.9883                1   -0.7031
# 205090           1.0078           0.9922                1   -0.7031
# 205091           1.0039           0.9922                1   -0.7031
# 205092                1           0.9961                1   -0.7031
#
#        PITCH ATT.1 PITCH ATT.2 PITCH ATT.3 PITCH ATT.4 CAP CLM 1 POSN  \
# 0          -0.3516     -0.3516     -0.3516     -0.3516         -0.001
# 1          -0.3516     -0.3516     -0.3516     -0.3516         -0.001
# 2          -0.3516     -0.3516     -0.3516     -0.3516         -0.001
# 3          -0.3516     -0.3516     -0.3516     -0.3516         -0.001
# 4          -0.3516     -0.3516     -0.3516     -0.3516         -0.001
# ...            ...         ...         ...         ...            ...
# 205088     -0.7031     -0.7031     -0.7031     -0.7031        -0.0021
# 205089     -0.7031     -0.7031     -0.7031     -0.7031        -0.0021
# 205090     -0.7031     -0.7031     -0.7031     -0.7031        -0.0021
# 205091     -0.7031     -0.7031     -0.7031     -0.7031        -0.0021
# 205092     -0.7031     -0.7031     -0.7031     -0.7031        -0.0021
#
#        CAP CLM 1 POSN.1  ... ROLL ATT ROLL ATT.1 CAP WHL 1 POSN  \
# 0                -0.001  ...   0.0879     0.0879         0.0115
# 1               -0.0021  ...   0.0879     0.0879         0.0104
# 2                -0.001  ...   0.0879     0.0879         0.0104
# 3                -0.001  ...   0.0879     0.0879         0.0104
# 4                -0.001  ...   0.0879     0.0879         0.0104
# ...                 ...  ...      ...        ...            ...
# 205088          -0.0021  ...   0.0879     0.0879         0.0084
# 205089          -0.0021  ...   0.0879     0.0879         0.0084
# 205090          -0.0021  ...   0.0879     0.0879         0.0084
# 205091          -0.0021  ...   0.0879     0.0879         0.0084
# 205092          -0.0021  ...   0.0879     0.0879         0.0084
#
#        CAP WHL 1 POSN.1 CAP WHL 1 POSN.2 CAP WHL 1 POSN.3 CAP WHL 1 POSN.4  \
# 0                0.0115           0.0115           0.0115           0.0115
# 1                0.0104           0.0115           0.0104           0.0115
# 2                0.0104           0.0104           0.0104           0.0104
# 3                0.0104           0.0104           0.0104           0.0104
# 4                0.0104           0.0104           0.0115           0.0104
# ...                 ...              ...              ...              ...
# 205088           0.0084           0.0084           0.0084           0.0084
# 205089           0.0084           0.0084           0.0094           0.0084
# 205090           0.0084           0.0084           0.0084           0.0084
# 205091           0.0084           0.0084           0.0084           0.0084
# 205092           0.0084           0.0084           0.0084           0.0084
#
#        N1 SELTED-L N1 SELTED-R MAGNETIC HEADING WIND DIR(ADIRU)  \
# 0             21.4        21.4            178.2               0
# 1             21.4        21.5            178.4               0
# 2             21.4        21.5            178.6               0
# 3             21.4        21.5            178.7               0
# 4             21.4        21.5            178.7               0
# ...            ...         ...              ...             ...
# 205088        21.1        21.2             88.9              83
# 205089          21        20.8             88.9              83
# 205090        21.1        18.9             88.9              83
# 205091        18.7        17.3             88.9              83
# 205092        16.9        15.8             88.9              83
#
#        WIND SPD(ADIRU) A/T ENGAGED ANY A/P ENGAGED    TRA-L  TRA-L.1    TRA-R  \
# 0                    0     DISENGD             OFF  34.0137  34.0137  34.0576
# 1                    0     DISENGD             OFF  34.0137  34.0137  34.0576
# 2                    0     DISENGD             OFF  33.9697  33.9697  34.0576
# 3                    0     DISENGD             OFF  33.9697  33.9697  34.0576
# 4                    0     DISENGD             OFF  33.9697  33.9697  34.0576
# ...                ...         ...             ...      ...      ...      ...
# 205088          49.125     DISENGD             OFF  33.9697  33.9697  34.0576
# 205089          49.125     DISENGD             OFF  33.9697  33.9697  34.0576
# 205090          49.125     DISENGD             OFF  33.9697  33.9697  34.0576
# 205091          49.125     DISENGD             OFF  33.9697  34.0137  34.0576
# 205092          49.125     DISENGD             OFF  34.0137  34.0137  34.0576
#
#         TRA-R.1 RUDD POSN GLIDESLOPE DEV Dots (C) GLIDESLOPE DEV Dots (L)  \
# 0       34.0576   -0.2617                   -0.49                   -0.58
# 1       34.0576   -0.2578                   -0.47                   -0.62
# 2       34.0576   -0.2578                    0.08                    0.26
# 3       34.0576   -0.2578                   -0.17                   -0.21
# 4       34.0576   -0.2578                   -0.05                       0
# ...         ...       ...                     ...                     ...
# 205088  34.0576   -0.2676                    1.26                    1.38
# 205089  34.0576   -0.2676                    1.29                    1.66
# 205090  34.0576   -0.2617                    1.86                    1.82
# 205091  34.0576   -0.2617                    1.45                       2
# 205092  34.0576   -0.2637                    1.71                    2.02
#
#        GLIDESLOPE DEV Dots (R) LOCALIZER DEV Dots (C) LOCALIZER DEV Dots (L)  \
# 0                        -0.29                  -3.17                  -3.04
# 1                        -0.36                  -2.78                  -2.78
# 2                         -0.1                  -3.06                  -2.96
# 3                         0.13                  -2.78                  -2.78
# 4                        -0.48                  -2.94                  -2.88
# ...                        ...                    ...                    ...
# 205088                    1.03                   2.67                   2.34
# 205089                     0.4                   2.48                    2.6
# 205090                    1.03                   2.22                    2.7
# 205091                    0.55                   2.33                   2.69
# 205092                    0.67                   2.41                   2.72
#
#        LOCALIZER DEV Dots (R) PITCH ATT RATE DEPARTURE AIRPORT  \
# 0                       -3.28         0.0625              机场68
# 1                       -2.95        -0.0625              机场68
# 2                       -3.18        -0.0625              机场68
# 3                       -2.92        -0.0625              机场68
# 4                       -3.09              0              机场68
# ...                       ...            ...               ...
# 205088                   2.76        -0.0625              机场73
# 205089                   2.56              0              机场73
# 205090                   2.29        -0.0625              机场73
# 205091                   2.39              0              机场73
# 205092                   2.43              0              机场73
#
#        DESTINATION AIRPORT PITCH ATT RATE.1 FMF GROSS WEIGHT
# 0                    机场117           0.0625           347680
# 1                    机场117          -0.0625           347680
# 2                    机场117          -0.0625           347680
# 3                    机场117          -0.0625           347680
# 4                    机场117                0           347680
# ...                    ...              ...              ...
# 205088                机场68          -0.0625           237920
# 205089                机场68                0           237920
# 205090                机场68          -0.0625           237920
# 205091                机场68                0           237920
# 205092                机场68                0           237920
#
# [205093 rows x 63 columns]

# %%
# Out:
#    x   y   z  mean_squared_row    rms_row
# 0  1   6  11         52.666667   7.257180
# 1  2   7  12         65.666667   8.103497
# 2  3   8  13         80.666667   8.981462
# 3  4   9  14         97.666667   9.882645
# 4  5  10  15        116.666667  10.801234

# %%
df3[' GEAR SELECT DOWN'] = df3[' GEAR SELECT DOWN'].replace({'DOWN':0, 'True': 1})
